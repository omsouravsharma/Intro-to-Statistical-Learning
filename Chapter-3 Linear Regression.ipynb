# %% [markdown]
# ### Linear Regression

# %% [markdown]
# Linear Equation
#
# y = b0 + b1*x where b0 and b1 reperent the intercept and slope.

# %% [markdown]
# Measuring the coefficient. Least Square approach.
# RSS - Residual sun of square.
# Residual is the difference between y - y (observed vs predicted)

# %% [markdown]
# Assessing the accuracy of the coefficient estimate.
# True relationship between X and Y =: y = f(X) + e where e is mean zero random error term.

# %%
# Import libraries 
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
rng = np.random.default_rng()

x = rng.random(100)
# x = rng.normal(size = (100))
# y = rng.normal(size = (100))
e = rng.normal(size = (100))

# %%
x
# Out:
# array([0.85721317, 0.36805089, 0.92037201, 0.89579873, 0.56450262,
#        0.75115639, 0.51521406, 0.64470188, 0.54043472, 0.49449061,
#        0.25877859, 0.3783459 , 0.98061163, 0.49407518, 0.50796307,
#        0.771488  , 0.02543375, 0.65496617, 0.2510123 , 0.68745408,
#        0.28380857, 0.12169819, 0.7009087 , 0.88435154, 0.99801393,
#        0.67426276, 0.41499503, 0.20558463, 0.56108722, 0.83702019,
#        0.31075826, 0.2611106 , 0.53412947, 0.07953057, 0.30010244,
#        0.15410395, 0.24652046, 0.75515416, 0.08457524, 0.78024353,
#        0.28284007, 0.48095134, 0.41967052, 0.07212434, 0.77479696,
#        0.10610576, 0.14025826, 0.49560283, 0.38321196, 0.16578022,
#        0.39398793, 0.55425713, 0.15915349, 0.52842921, 0.37778276,
#        0.9221754 , 0.46827081, 0.26415894, 0.61897113, 0.77018186,
#        0.59315703, 0.83651513, 0.93639205, 0.76510274, 0.90759406,
#        0.7670779 , 0.05060897, 0.89686469, 0.59842297, 0.08647055,
#        0.78611546, 0.404424  , 0.65489647, 0.59977096, 0.74699218,
#        0.70590803, 0.27893635, 0.56458865, 0.87234431, 0.14436923,
#        0.43624684, 0.32971578, 0.54276626, 0.32354697, 0.99635073,
#        0.66879723, 0.60286071, 0.90318457, 0.85904575, 0.3679757 ,
#        0.82753417, 0.39844933, 0.69661778, 0.21514942, 0.68699216,
#        0.59418668, 0.0999394 , 0.72571849, 0.81757654, 0.92917155])

# %%
y = 2 + 3*x + e
y
# Out:
# array([5.33973744, 4.28173515, 3.54403409, 5.22421089, 3.61810932,
#        4.8903104 , 2.73371882, 4.00598269, 3.59148907, 3.79128501,
#        3.53593312, 3.71057395, 3.02761547, 4.71241361, 2.86338561,
#        3.62544092, 3.01441182, 5.52286502, 3.98555514, 3.11968811,
#        2.37110642, 2.54489626, 2.76998152, 5.73795881, 5.64289834,
#        5.59486149, 3.75084004, 2.45967333, 4.80478388, 3.67101052,
#        3.5958946 , 0.93934144, 3.81831011, 2.29525938, 3.13709173,
#        4.14186227, 1.80863164, 6.24168124, 2.30455088, 4.92860555,
#        0.80238534, 2.07989942, 2.84912086, 0.61782956, 5.16346497,
#        2.35941575, 3.28135366, 5.35707791, 2.99279267, 1.90065249,
#        4.26550112, 2.90308018, 2.14093195, 2.96849667, 1.55805478,
#        4.75148624, 4.70394497, 1.35817362, 3.67218868, 3.92395086,
#        4.43199496, 3.85986394, 5.54993148, 4.52535407, 4.30052145,
#        4.1194911 , 1.63745774, 4.99593456, 5.41783811, 2.53812827,
#        4.91321056, 3.57132139, 3.07018058, 3.91631049, 5.67246643,
#        4.0952667 , 2.46159995, 4.2851161 , 3.52674446, 2.83015501,
#        4.00237841, 2.56251204, 4.00060182, 1.77315567, 5.06890439,
#        4.10594787, 3.73581434, 5.13349999, 3.84349561, 3.67787707,
#        3.47824298, 1.79109643, 3.45283693, 2.43236988, 3.71293708,
#        3.44470019, 2.06623914, 2.60855356, 4.50478759, 3.56148142])

# %%
plt.hist(y)
# Out:
# (array([ 3.,  3.,  9., 14.,  9., 26., 14.,  9., 11.,  2.]),
#  array([0.61782956, 1.18021473, 1.74259989, 2.30498506, 2.86737023,
#         3.4297554 , 3.99214057, 4.55452574, 5.11691091, 5.67929607,
#         6.24168124]),
#  <BarContainer object of 10 artists>)

# %%
plt.plot(x)

# %%
plt.plot(y)

# %%
plt.plot(x,y,)

# %%
plt.scatter(x,y)

# %%
# np.polynomial fit

m_slope, b_intercept = np.polynomial.polynomial.polyfit(x, y , 1)
m_slope, b_intercept
# Out:
# (1.9891207784194873, 3.00132046456545)

# %%
plt.plot(x,y, 'o', color='green')
plt.plot(x, 2 + 3*x, color='red') # True relationship known as population regression line.
plt.plot(x, m_slope*x + b_intercept, color='blue') # Least square estimate for f(X)

# %%
# Visualizing using seaborn library
sns.jointplot(x=x, y=y, ci=None, kind='reg')
